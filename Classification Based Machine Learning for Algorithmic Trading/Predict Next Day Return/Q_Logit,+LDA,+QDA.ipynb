# %% [markdown]
# # Predicting Price Returns
#
# [Forecasting Financial Time Series - Part I](https://www.quantstart.com/articles/Forecasting-Financial-Time-Series-Part-1)

# %% [markdown]
# ## Other references
#
# http://francescopochetti.com/stock-market-prediction-part-introduction/
#
#
# https://www.cs.princeton.edu/sites/default/files/uploads/saahil_madge.pdf
#
# https://www.quantstart.com/articles

# %%
import datetime
import numpy as np
import pandas as pd
import sklearn

from sklearn.linear_model import LogisticRegression
from sklearn.lda import LDA
from sklearn.qda import QDA

# %%
symbol = 'SPY'
start_date = '2012-01-01'
end_date = '2016-12-31'
lags = 5

start_test = '2016-06-01'

# %%
ts = get_pricing('SPY', start_date, end_date)
ts.head()
# Out:
#                            open_price     high      low  close_price  \
# 2012-01-03 00:00:00+00:00     116.080  116.643  115.780      115.925
# 2012-01-04 00:00:00+00:00     115.571  116.125  115.126      116.007
# 2012-01-05 00:00:00+00:00     115.398  116.506  114.871      116.352
# 2012-01-06 00:00:00+00:00     116.478  116.497  115.653      116.107
# 2012-01-09 00:00:00+00:00     116.298  116.461  115.762      116.298
#
#                                 volume    price
# 2012-01-03 00:00:00+00:00  145314347.0  115.925
# 2012-01-04 00:00:00+00:00  105644656.0  116.007
# 2012-01-05 00:00:00+00:00  143200079.0  116.352
# 2012-01-06 00:00:00+00:00  119860034.0  116.107
# 2012-01-09 00:00:00+00:00   85232476.0  116.298

# %%
tslag = ts[['price']].copy()
tslag
# Out:
#                              price
# 2012-01-03 00:00:00+00:00  115.925
# 2012-01-04 00:00:00+00:00  116.007
# 2012-01-05 00:00:00+00:00  116.352
# 2012-01-06 00:00:00+00:00  116.107
# 2012-01-09 00:00:00+00:00  116.298
# 2012-01-10 00:00:00+00:00  117.352
# 2012-01-11 00:00:00+00:00  117.424
# 2012-01-12 00:00:00+00:00  117.688
# 2012-01-13 00:00:00+00:00  117.160
# 2012-01-17 00:00:00+00:00  117.506
# 2012-01-18 00:00:00+00:00  118.823
# 2012-01-19 00:00:00+00:00  119.459
# 2012-01-20 00:00:00+00:00  119.514
# 2012-01-23 00:00:00+00:00  119.568
# 2012-01-24 00:00:00+00:00  119.441
# 2012-01-25 00:00:00+00:00  120.450
# 2012-01-26 00:00:00+00:00  119.823
# 2012-01-27 00:00:00+00:00  119.668
# 2012-01-30 00:00:00+00:00  119.350
# 2012-01-31 00:00:00+00:00  119.241
# 2012-02-01 00:00:00+00:00  120.341
# 2012-02-02 00:00:00+00:00  120.541
# 2012-02-03 00:00:00+00:00  122.249
# 2012-02-06 00:00:00+00:00  122.158
# 2012-02-07 00:00:00+00:00  122.458
# 2012-02-08 00:00:00+00:00  122.776
# 2012-02-09 00:00:00+00:00  122.976
# 2012-02-10 00:00:00+00:00  122.085
# 2012-02-13 00:00:00+00:00  122.957
# 2012-02-14 00:00:00+00:00  122.867
# ...                            ...
# 2016-11-17 00:00:00+00:00  217.667
# 2016-11-18 00:00:00+00:00  217.230
# 2016-11-21 00:00:00+00:00  218.820
# 2016-11-22 00:00:00+00:00  219.238
# 2016-11-23 00:00:00+00:00  219.437
# 2016-11-25 00:00:00+00:00  220.232
# 2016-11-28 00:00:00+00:00  219.238
# 2016-11-29 00:00:00+00:00  219.596
# 2016-11-30 00:00:00+00:00  219.039
# 2016-12-01 00:00:00+00:00  218.244
# 2016-12-02 00:00:00+00:00  218.383
# 2016-12-05 00:00:00+00:00  219.646
# 2016-12-06 00:00:00+00:00  220.391
# 2016-12-07 00:00:00+00:00  223.254
# 2016-12-08 00:00:00+00:00  223.811
# 2016-12-09 00:00:00+00:00  225.163
# 2016-12-12 00:00:00+00:00  224.895
# 2016-12-13 00:00:00+00:00  226.386
# 2016-12-14 00:00:00+00:00  224.586
# 2016-12-15 00:00:00+00:00  225.491
# 2016-12-16 00:00:00+00:00  225.070
# 2016-12-19 00:00:00+00:00  225.500
# 2016-12-20 00:00:00+00:00  226.370
# 2016-12-21 00:00:00+00:00  225.800
# 2016-12-22 00:00:00+00:00  225.400
# 2016-12-23 00:00:00+00:00  225.690
# 2016-12-27 00:00:00+00:00  226.240
# 2016-12-28 00:00:00+00:00  224.420
# 2016-12-29 00:00:00+00:00  224.360
# 2016-12-30 00:00:00+00:00  223.550
#
# [1258 rows x 1 columns]

# %% [raw]
# tslag["Today"] = ts["price"]
# tslag["Volume"] = ts["volume"]

# %%
for i in xrange(0,lags):
    tslag["Lag_" + str(i+1)] = tslag["price"].shift(i+1)
tslag["returns"] = tslag["price"].pct_change()
tslag.head(10)
# Out:
#                              price    Lag_1    Lag_2    Lag_3    Lag_4  \
# 2012-01-03 00:00:00+00:00  115.925      NaN      NaN      NaN      NaN
# 2012-01-04 00:00:00+00:00  116.007  115.925      NaN      NaN      NaN
# 2012-01-05 00:00:00+00:00  116.352  116.007  115.925      NaN      NaN
# 2012-01-06 00:00:00+00:00  116.107  116.352  116.007  115.925      NaN
# 2012-01-09 00:00:00+00:00  116.298  116.107  116.352  116.007  115.925
# 2012-01-10 00:00:00+00:00  117.352  116.298  116.107  116.352  116.007
# 2012-01-11 00:00:00+00:00  117.424  117.352  116.298  116.107  116.352
# 2012-01-12 00:00:00+00:00  117.688  117.424  117.352  116.298  116.107
# 2012-01-13 00:00:00+00:00  117.160  117.688  117.424  117.352  116.298
# 2012-01-17 00:00:00+00:00  117.506  117.160  117.688  117.424  117.352
#
#                              Lag_5   returns
# 2012-01-03 00:00:00+00:00      NaN       NaN
# 2012-01-04 00:00:00+00:00      NaN  0.000707
# 2012-01-05 00:00:00+00:00      NaN  0.002974
# 2012-01-06 00:00:00+00:00      NaN -0.002106
# 2012-01-09 00:00:00+00:00      NaN  0.001645
# 2012-01-10 00:00:00+00:00  115.925  0.009063
# 2012-01-11 00:00:00+00:00  116.007  0.000614
# 2012-01-12 00:00:00+00:00  116.352  0.002248
# 2012-01-13 00:00:00+00:00  116.107 -0.004486
# 2012-01-17 00:00:00+00:00  116.298  0.002953

# %%
# If any of the values of percentage returns equal zero, set them to
# a small number (stops issues with QDA model in scikit-learn)
for k, v in enumerate(tslag["returns"]):
    if (abs(v) < 0.0001):
        tslag["returns"][k] = 0.0001

# %%
# Create the lagged percentage returns columns
for i in xrange(0, lags):
    tslag["Lag_returns_" + str(i+1)] = tslag["Lag_" + str(i+1)].pct_change()

# %%
tslag.head(7)
# Out:
#                              price    Lag_1    Lag_2    Lag_3    Lag_4  \
# 2012-01-03 00:00:00+00:00  115.925      NaN      NaN      NaN      NaN
# 2012-01-04 00:00:00+00:00  116.007  115.925      NaN      NaN      NaN
# 2012-01-05 00:00:00+00:00  116.352  116.007  115.925      NaN      NaN
# 2012-01-06 00:00:00+00:00  116.107  116.352  116.007  115.925      NaN
# 2012-01-09 00:00:00+00:00  116.298  116.107  116.352  116.007  115.925
# 2012-01-10 00:00:00+00:00  117.352  116.298  116.107  116.352  116.007
# 2012-01-11 00:00:00+00:00  117.424  117.352  116.298  116.107  116.352
#
#                              Lag_5   returns  Lag_returns_1  Lag_returns_2  \
# 2012-01-03 00:00:00+00:00      NaN       NaN            NaN            NaN
# 2012-01-04 00:00:00+00:00      NaN  0.000707            NaN            NaN
# 2012-01-05 00:00:00+00:00      NaN  0.002974       0.000707            NaN
# 2012-01-06 00:00:00+00:00      NaN -0.002106       0.002974       0.000707
# 2012-01-09 00:00:00+00:00      NaN  0.001645      -0.002106       0.002974
# 2012-01-10 00:00:00+00:00  115.925  0.009063       0.001645      -0.002106
# 2012-01-11 00:00:00+00:00  116.007  0.000614       0.009063       0.001645
#
#                            Lag_returns_3  Lag_returns_4  Lag_returns_5
# 2012-01-03 00:00:00+00:00            NaN            NaN            NaN
# 2012-01-04 00:00:00+00:00            NaN            NaN            NaN
# 2012-01-05 00:00:00+00:00            NaN            NaN            NaN
# 2012-01-06 00:00:00+00:00            NaN            NaN            NaN
# 2012-01-09 00:00:00+00:00       0.000707            NaN            NaN
# 2012-01-10 00:00:00+00:00       0.002974       0.000707            NaN
# 2012-01-11 00:00:00+00:00      -0.002106       0.002974       0.000707

# %%
# Create the "Direction" column (+1 or -1) indicating an up/down day
tslag["Direction"] = np.sign(tslag["returns"])
#tslag = tslag[tslag.index >= start_date]
tslag.dropna(inplace=True)
tslag.head()
# Out:
#                              price    Lag_1    Lag_2    Lag_3    Lag_4  \
# 2012-01-11 00:00:00+00:00  117.424  117.352  116.298  116.107  116.352
# 2012-01-12 00:00:00+00:00  117.688  117.424  117.352  116.298  116.107
# 2012-01-13 00:00:00+00:00  117.160  117.688  117.424  117.352  116.298
# 2012-01-17 00:00:00+00:00  117.506  117.160  117.688  117.424  117.352
# 2012-01-18 00:00:00+00:00  118.823  117.506  117.160  117.688  117.424
#
#                              Lag_5   returns  Lag_returns_1  Lag_returns_2  \
# 2012-01-11 00:00:00+00:00  116.007  0.000614       0.009063       0.001645
# 2012-01-12 00:00:00+00:00  116.352  0.002248       0.000614       0.009063
# 2012-01-13 00:00:00+00:00  116.107 -0.004486       0.002248       0.000614
# 2012-01-17 00:00:00+00:00  116.298  0.002953      -0.004486       0.002248
# 2012-01-18 00:00:00+00:00  117.352  0.011208       0.002953      -0.004486
#
#                            Lag_returns_3  Lag_returns_4  Lag_returns_5  \
# 2012-01-11 00:00:00+00:00      -0.002106       0.002974       0.000707
# 2012-01-12 00:00:00+00:00       0.001645      -0.002106       0.002974
# 2012-01-13 00:00:00+00:00       0.009063       0.001645      -0.002106
# 2012-01-17 00:00:00+00:00       0.000614       0.009063       0.001645
# 2012-01-18 00:00:00+00:00       0.002248       0.000614       0.009063
#
#                            Direction
# 2012-01-11 00:00:00+00:00        1.0
# 2012-01-12 00:00:00+00:00        1.0
# 2012-01-13 00:00:00+00:00       -1.0
# 2012-01-17 00:00:00+00:00        1.0
# 2012-01-18 00:00:00+00:00        1.0

# %%
# Use the prior two days of returns as predictor values, with direction as the response
X = tslag[["Lag_1","Lag_2"]]
y = tslag["Direction"]

# %%
# Create training and test sets
X_train = X[X.index < start_test]
X_test = X[X.index >= start_test]
y_train = y[y.index < start_test]
y_test = y[y.index >= start_test]

# %%
# Create prediction DataFrame
pred = pd.DataFrame(index=y_test.index)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
pred = (1.0 + y_pred * y_test)/2.0
hit_rate = np.mean(pred)
print('Logistic Regresstion {:.3f}').format(hit_rate)
# Out:
# Logistic Regresstion 0.523

# %%
lda = LDA()
lda.fit(X_train, y_train)
y_pred = lda.predict(X_test)
pred = (1.0 + y_pred * y_test)/2.0
hit_rate = np.mean(pred)
print('LDA {:.3f}').format(hit_rate)
# Out:
# LDA 0.523

# %%
models = QDA()
models.fit(X_train, y_train)
y_pred = models.predict(X_test)
pred = (1.0 + y_pred * y_test)/2.0
hit_rate = np.mean(pred)
print('QDA {:.3f}').format(hit_rate)
# Out:
# QDA 0.570

# %% [markdown]
# ***
