# %% [markdown]
# # Tear Sheet for Applying QDA ML on SPY
#
# ## For the period from 2005-01-03 till 2009-12-31

# %%
bt = get_backtest('5983ea688c985b4fc3d75cbe')
# Out:
# 100% Time: 0:00:00|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2005-01-03
# Entire data end date: 2009-12-31
#
#
# Backtest Months: 59
# Performance statistics   Backtest
# annual_return               -0.06
# cum_returns_final           -0.28
# annual_volatility            0.16
# sharpe_ratio                -0.33
# calmar_ratio                -0.12
# stability_of_timeseries      0.53
# max_drawdown                -0.52
# omega_ratio                  0.92
# sortino_ratio               -0.42
# skew                        -1.66
# kurtosis                    17.68
# tail_ratio                   0.95
# common_sense_ratio           0.89
# gross_leverage               0.57
# information_ratio           -0.03
# alpha                       -0.07
# beta                         0.48
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  51.56 2006-03-16  2009-03-09           NaT
# 1                                   5.92 2005-03-07  2005-04-20    2005-05-19
# 2                                   3.50 2005-09-09  2005-10-18    2005-11-23
# 3                                   2.60 2005-06-17  2005-07-06    2005-09-06
# 4                                   2.04 2005-01-18  2005-01-28    2005-02-08
#
# Worst drawdown periods duration
# 0                           NaN
# 1                            54
# 2                            54
# 3                            58
# 4                            16
# [-0.02 -0.04]
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# Stress Events                mean    min   max
# Lehmann                    -0.35% -7.03% 3.34%
# Aug07                       0.03% -2.78% 2.25%
# Mar08                      -0.02% -0.94% 1.84%
# Sept08                     -0.49% -7.03% 3.34%
# 2009Q1                     -0.36% -5.13% 4.17%
# 2009Q2                      0.26% -4.27% 6.00%
# Low Volatility Bull Market  0.01% -2.03% 1.82%
# GFC Crash                  -0.14% -8.59% 6.00%
# Recovery                    0.12% -4.27% 3.49%
# Top 10 long positions of all time     max
# SPY-8554                          100.46%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time     max
# SPY-8554                     100.46%
# All positions ever held     max
# SPY-8554                100.46%

# %% [markdown]
# # Conclusion
#
# Before we start digging into the performance, it pays to recall that we only tested this on single asset (SPY). No fund manager would bet all the funds in a single counter. This exercise is really to help us develop an intuitive understanding of how the Logistric Regression ML perform in different market conditions.
#
# We can conclude that the performance is rather poor and not very exciting really.
#
# # Extensions
#
# It would be wise to look at extending the above study with the following variations:
#
# 1. More assets
# 2. More factors
# 3. Varying training period

# %% [markdown]
# ***

# %% [markdown]
# ***
