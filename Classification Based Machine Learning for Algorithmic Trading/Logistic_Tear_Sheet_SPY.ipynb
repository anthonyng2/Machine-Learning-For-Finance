# %% [markdown]
# # Tear Sheet for Applying Logistic Regression ML on SPY
#
# ## For the period from 2005-01-03 till 2009-12-31

# %%
bt = get_backtest('5983e9848c985b4fc3d75c47')
# Out:
# 100% Time: 0:00:01|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2005-01-03
# Entire data end date: 2008-09-18
#
#
# Backtest Months: 44
# Performance statistics   Backtest
# annual_return                0.03
# cum_returns_final            0.11
# annual_volatility            0.15
# sharpe_ratio                 0.27
# calmar_ratio                 0.14
# stability_of_timeseries      0.60
# max_drawdown                -0.21
# omega_ratio                  1.05
# sortino_ratio                0.37
# skew                        -0.22
# kurtosis                     2.48
# tail_ratio                   0.94
# common_sense_ratio           0.97
# gross_leverage               1.00
# information_ratio            0.03
# alpha                        0.01
# beta                         0.97
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  21.49 2007-10-09  2008-09-15           NaT
# 1                                   8.81 2007-07-19  2007-08-15    2007-10-01
# ...

# %% [markdown]
# # Conclusion
#
# Before we start digging into the performance, it pays to recall that we only tested this on single asset (SPY). No fund manager would bet all the funds in a single counter. This exercise is really to help us develop an intuitive understanding of how the Logistric Regression ML perform in different market conditions.
#
# We can conclude that the performance is rather poor and not very exciting really.
#
# # Extensions
#
# It would be wise to look at extending the above study with the following variations:
#
# 1. More assets
# 2. More factors
# 3. Varying training period

# %% [markdown]
# ***

# %% [markdown]
# # Tear Sheet for Applying Logistic Regression ML on Boeing
#
# ## For the period from 2010-01-04 till 2016-12-30

# %%
bt = get_backtest('5983e9b58c985b4fc3d75c55')
# Out:
# 100% Time: 0:00:00|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2010-01-04
# Entire data end date: 2016-10-24
#
#
# Backtest Months: 81
# Performance statistics   Backtest
# annual_return                0.12
# cum_returns_final            1.14
# annual_volatility            0.15
# sharpe_ratio                 0.80
# calmar_ratio                 0.61
# stability_of_timeseries      0.95
# max_drawdown                -0.19
# omega_ratio                  1.15
# sortino_ratio                1.13
# skew                        -0.40
# kurtosis                     3.58
# tail_ratio                   0.96
# common_sense_ratio           1.07
# gross_leverage               1.00
# information_ratio           -0.00
# alpha                        0.00
# beta                         0.97
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  19.24 2010-04-23  2010-07-02    2011-01-03
# 1                                  17.32 2011-04-29  2011-08-08    2012-01-18
# ...

# %% [markdown]
# The performance for the latter period is not much better. We can pretty much conclude that there's no predictive value in this ML with the current setup.

# %% [markdown]
# ***
