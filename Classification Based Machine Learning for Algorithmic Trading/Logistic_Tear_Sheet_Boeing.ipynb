# %% [markdown]
# # Tear Sheet for Applying Logistic Regression ML on Boeing
#
# ## For the period from 2005-01-03 till 2009-12-31

# %%
bt = get_backtest('5983e6c3cc46c14fa330ca9b')
# Out:
# 100% Time: 0:00:01|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2005-01-03
# Entire data end date: 2009-12-31
#
#
# Backtest Months: 59
# Performance statistics   Backtest
# annual_return                0.01
# cum_returns_final            0.05
# annual_volatility            0.22
# sharpe_ratio                 0.15
# calmar_ratio                 0.02
# stability_of_timeseries      0.12
# max_drawdown                -0.61
# omega_ratio                  1.03
# sortino_ratio                0.21
# skew                        -0.25
# kurtosis                     4.59
# tail_ratio                   0.97
# common_sense_ratio           0.98
# gross_leverage               0.74
# information_ratio            0.00
# alpha                        0.02
# beta                         0.44
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  60.66 2007-07-25  2009-04-20           NaT
# 1                                  20.38 2006-05-10  2006-09-08    2007-04-18
# ...

# %% [markdown]
# # Conclusion
#
# Before we start digging into the performance, it pays to recall that we only tested this on single asset (Boeing). No fund manager would bet all the funds in a single counter. This exercise is really to help us develop an intuitive understanding of how the Logistric Regression ML perform in different market conditions.
#
# # Extensions
#
# It would be wise to look at extending the above study with the following variations:
#
# 1. More assets
# 2. More factors
# 3. Varying training period

# %% [markdown]
# ***

# %% [markdown]
# # Tear Sheet for Applying Logistic Regression ML on Boeing
#
# ## For the period from 2010-01-04 till 2016-12-30

# %%
bt = get_backtest('5983e785ff66794fa2a4bed1')
# Out:
# 100% Time: 0:00:01|###########################################################|

# %%
bt.create_full_tear_sheet()
# Out:
# Entire data start date: 2010-01-04
# Entire data end date: 2016-12-30
#
#
# Backtest Months: 83
# Performance statistics   Backtest
# annual_return                0.08
# cum_returns_final            0.73
# annual_volatility            0.19
# sharpe_ratio                 0.50
# calmar_ratio                 0.27
# stability_of_timeseries      0.63
# max_drawdown                -0.30
# omega_ratio                  1.10
# sortino_ratio                0.72
# skew                        -0.21
# kurtosis                     4.51
# tail_ratio                   1.00
# common_sense_ratio           1.09
# gross_leverage               0.81
# information_ratio           -0.01
# alpha                        0.00
# beta                         0.73
# Worst drawdown periods net drawdown in %  peak date valley date recovery date  \
# 0                                  30.05 2015-02-20  2016-02-16           NaT
# 1                                  27.15 2010-04-22  2013-01-31    2013-06-07
# ...
